# %%
import random
p=input('enter the name of the player:')
c='computer'
players=[p,c]
n=random.choice(players)
current_player=n
total=0
total1=0

def toss():
    global d
    global r
    t=['head','tail']
    d=input('enter head or tail:')
    r=random.choice(t)
    print(r)
    
    
def choice():
    global b
    global y
    global x
    if d==r:
        b=input('choose ball or bat:')
        if b=='bat':
            print(p,'choose bat first')
        else:
            print(p,'choose ball first')
    else:
        x=['ball','bat']
        import random
        y=random.choice(x)
        print('computer choose first',y)


def computer1():
    global z
    import random
    a=[0,1,2,3,4,5,6]
    z=random.choice(a)
    z=int(z)
    print('computer score',z)
    
    
def player1():
    global s
    s=input('enter the number between 0 and 6:')
    if s=='0' or s=='1' or s=='2' or s=='3' or s=='4' or s=='5' or s=='6':
        s=int(s)
        print(p,'score:',s)


def playing_p():
    global total
    total=0
    while True:
        global s
        s=input('enter the number between 0 and 6:')
        if s=='0' or s=='1' or s=='2' or s=='3' or s=='4' or s=='5' or s=='6':
            s=int(s)
            print(p,'score:',s)
            computer1()
            total=total+s
            if batting=='second':
                if total>total1:
                    print(p,'won')
                    break
            if s==z:
                print('OUT')
                print('the final score is',total-s)
                print()
                break
            else:
                print('the score is:',total)
        else:
            pass

def playing_c():
    global total1
    total1=0
    while True:
        global z
        import random
        a=[0,1,2,3,4,5,6]
        z=random.choice(a)
        z=int(z)
        player1()
        print('computer score',z)
        total1=total1+z
        if batting=='second':
            if total1>total:
                print('computer won')
                break
        if z==s:
            print('OUT')
            print('the final score is',total1-z)
            print()
            break
        else:
            print('the score is:',total1)



def playing():
    global batting
    batting ='first'
    if d==r:
        if b=='bat':
            playing_p()
        else:
            playing_c()
    else:
        y==x
        if y=='bat':
            playing_c()
        else:
            playing_p()
            
            
def playing2():
    global batting
    batting ='second'
    if d==r:
        if b=='ball':
            playing_p()
        else:
            playing_c()
    else:
        y==x
        if y=='ball':
            playing_c()
        else:
            playing_p()

            
            
            
toss()
choice()
playing()
print('second batting')
playing2()
# Out:
# enter the name of the player:arya
# enter head or tail:tail
# head
# computer choose first ball
# enter the number between 0 and 6:3
# arya score: 3
# computer score 0
# the score is: 3
# enter the number between 0 and 6:1
# arya score: 1
# computer score 5
# the score is: 4
# enter the number between 0 and 6:2
# arya score: 2
# computer score 6
# the score is: 6
# enter the number between 0 and 6:3
# arya score: 3
# computer score 2
# the score is: 9
# enter the number between 0 and 6:
# enter the number between 0 and 6:5
# arya score: 5
# computer score 4
# the score is: 14
# enter the number between 0 and 6:4
# arya score: 4
# computer score 0
# the score is: 18
# enter the number between 0 and 6:3
# arya score: 3
# computer score 0
# the score is: 21
# enter the number between 0 and 6:2
# arya score: 2
# computer score 1
# the score is: 23
# enter the number between 0 and 6:1
# arya score: 1
# computer score 5
# the score is: 24
# enter the number between 0 and 6:2
# ...

# %% [markdown]
# #####
